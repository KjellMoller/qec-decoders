# %%
# %pip install stim
# %pip install sinter
# %pip install numpy
# %pip install matplotlib
# %pip install stimbposd
# %pip install ldpc
# Out:
# Requirement already satisfied: stim in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (1.16.0)
# Requirement already satisfied: numpy in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (from stim) (2.3.3)
#
# [notice] A new release of pip is available: 25.2 -> 26.1.2
# [notice] To update, run: pip install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.
# Requirement already satisfied: sinter in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (1.16.0)
# Requirement already satisfied: matplotlib in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (from sinter) (3.10.7)
# Requirement already satisfied: numpy in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (from sinter) (2.3.3)
# Requirement already satisfied: stim in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (from sinter) (1.16.0)
# Requirement already satisfied: scipy in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (from sinter) (1.16.2)
# Requirement already satisfied: contourpy>=1.0.1 in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (from matplotlib->sinter) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (from matplotlib->sinter) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (from matplotlib->sinter) (4.60.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (from matplotlib->sinter) (1.4.9)
# Requirement already satisfied: packaging>=20.0 in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (from matplotlib->sinter) (25.0)
# Requirement already satisfied: pillow>=8 in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (from matplotlib->sinter) (12.0.0)
# Requirement already satisfied: pyparsing>=3 in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (from matplotlib->sinter) (3.2.5)
# Requirement already satisfied: python-dateutil>=2.7 in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (from matplotlib->sinter) (2.9.0.post0)
# Requirement already satisfied: six>=1.5 in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (from python-dateutil>=2.7->matplotlib->sinter) (1.17.0)
#
# [notice] A new release of pip is available: 25.2 -> 26.1.2
# [notice] To update, run: pip install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.
# Requirement already satisfied: numpy in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (2.3.3)
#
# [notice] A new release of pip is available: 25.2 -> 26.1.2
# [notice] To update, run: pip install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.
# Requirement already satisfied: matplotlib in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (3.10.7)
# Requirement already satisfied: contourpy>=1.0.1 in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (from matplotlib) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (from matplotlib) (4.60.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (from matplotlib) (1.4.9)
# Requirement already satisfied: numpy>=1.23 in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (from matplotlib) (2.3.3)
# Requirement already satisfied: packaging>=20.0 in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (from matplotlib) (25.0)
# Requirement already satisfied: pillow>=8 in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (from matplotlib) (12.0.0)
# Requirement already satisfied: pyparsing>=3 in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (from matplotlib) (3.2.5)
# Requirement already satisfied: python-dateutil>=2.7 in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (from matplotlib) (2.9.0.post0)
# Requirement already satisfied: six>=1.5 in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (from python-dateutil>=2.7->matplotlib) (1.17.0)
#
# [notice] A new release of pip is available: 25.2 -> 26.1.2
# [notice] To update, run: pip install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.
# Requirement already satisfied: stimbposd in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (0.2.0)
# Requirement already satisfied: ldpc in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (from stimbposd) (2.4.1)
# Requirement already satisfied: numpy in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (from stimbposd) (2.3.3)
# Requirement already satisfied: sinter>=1.12.0 in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (from stimbposd) (1.16.0)
# Requirement already satisfied: stim in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (from stimbposd) (1.16.0)
# Requirement already satisfied: matplotlib in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (from sinter>=1.12.0->stimbposd) (3.10.7)
# Requirement already satisfied: scipy in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (from sinter>=1.12.0->stimbposd) (1.16.2)
# Requirement already satisfied: tqdm in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (from ldpc->stimbposd) (4.67.1)
# Requirement already satisfied: pytest in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (from ldpc->stimbposd) (9.1.0)
# Requirement already satisfied: pymatching in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (from ldpc->stimbposd) (2.4.0)
# Requirement already satisfied: contourpy>=1.0.1 in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (from matplotlib->sinter>=1.12.0->stimbposd) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (from matplotlib->sinter>=1.12.0->stimbposd) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (from matplotlib->sinter>=1.12.0->stimbposd) (4.60.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (from matplotlib->sinter>=1.12.0->stimbposd) (1.4.9)
# Requirement already satisfied: packaging>=20.0 in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (from matplotlib->sinter>=1.12.0->stimbposd) (25.0)
# Requirement already satisfied: pillow>=8 in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (from matplotlib->sinter>=1.12.0->stimbposd) (12.0.0)
# Requirement already satisfied: pyparsing>=3 in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (from matplotlib->sinter>=1.12.0->stimbposd) (3.2.5)
# Requirement already satisfied: python-dateutil>=2.7 in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (from matplotlib->sinter>=1.12.0->stimbposd) (2.9.0.post0)
# Requirement already satisfied: six>=1.5 in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (from python-dateutil>=2.7->matplotlib->sinter>=1.12.0->stimbposd) (1.17.0)
# Requirement already satisfied: networkx in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (from pymatching->ldpc->stimbposd) (3.5)
# Requirement already satisfied: iniconfig>=1.0.1 in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (from pytest->ldpc->stimbposd) (2.3.0)
# Requirement already satisfied: pluggy<2,>=1.5 in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (from pytest->ldpc->stimbposd) (1.6.0)
# Requirement already satisfied: pygments>=2.7.2 in /Users/kjellmoller/Library/Python/3.13/lib/python/site-packages (from pytest->ldpc->stimbposd) (2.19.2)
#
# [notice] A new release of pip is available: 25.2 -> 26.1.2
# [notice] To update, run: pip install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.
# Requirement already satisfied: ldpc in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (2.4.1)
# Requirement already satisfied: numpy>=1.24.0 in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (from ldpc) (2.3.3)
# Requirement already satisfied: scipy>=1.9.3 in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (from ldpc) (1.16.2)
# Requirement already satisfied: tqdm in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (from ldpc) (4.67.1)
# Requirement already satisfied: pytest in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (from ldpc) (9.1.0)
# Requirement already satisfied: stim in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (from ldpc) (1.16.0)
# Requirement already satisfied: sinter>=1.12.0 in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (from ldpc) (1.16.0)
# Requirement already satisfied: pymatching in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (from ldpc) (2.4.0)
# Requirement already satisfied: matplotlib in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (from sinter>=1.12.0->ldpc) (3.10.7)
# Requirement already satisfied: contourpy>=1.0.1 in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (from matplotlib->sinter>=1.12.0->ldpc) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (from matplotlib->sinter>=1.12.0->ldpc) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (from matplotlib->sinter>=1.12.0->ldpc) (4.60.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (from matplotlib->sinter>=1.12.0->ldpc) (1.4.9)
# Requirement already satisfied: packaging>=20.0 in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (from matplotlib->sinter>=1.12.0->ldpc) (25.0)
# Requirement already satisfied: pillow>=8 in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (from matplotlib->sinter>=1.12.0->ldpc) (12.0.0)
# Requirement already satisfied: pyparsing>=3 in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (from matplotlib->sinter>=1.12.0->ldpc) (3.2.5)
# Requirement already satisfied: python-dateutil>=2.7 in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (from matplotlib->sinter>=1.12.0->ldpc) (2.9.0.post0)
# Requirement already satisfied: six>=1.5 in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (from python-dateutil>=2.7->matplotlib->sinter>=1.12.0->ldpc) (1.17.0)
# Requirement already satisfied: networkx in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (from pymatching->ldpc) (3.5)
# Requirement already satisfied: iniconfig>=1.0.1 in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (from pytest->ldpc) (2.3.0)
# Requirement already satisfied: pluggy<2,>=1.5 in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (from pytest->ldpc) (1.6.0)
# Requirement already satisfied: pygments>=2.7.2 in /Users/kjellmoller/Library/Python/3.13/lib/python/site-packages (from pytest->ldpc) (2.19.2)
#
# [notice] A new release of pip is available: 25.2 -> 26.1.2
# [notice] To update, run: pip install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.

# %%
import stim
import sinter
import numpy as np

# Decoder imports
import pymatching
import ldpc
from ldpc.sinter_decoders import SinterBpOsdDecoder, SinterLsdDecoder
from sinter_decoders.sinter_unionfind_decoder import SinterUnionFindDecoder

# Plotting
import matplotlib.pyplot as plt

# %%
distances = [3, 5,7]
dep_error_rates = np.linspace(1e-4, 1e-2, 20)

# Source: adapted from https://github.com/quantumlib/Stim/blob/01f1aabd0fbc64d6943d42094a4bde96818399bd/doc/getting_started.ipynb

tasks = [
    sinter.Task(
        circuit=stim.Circuit.generated(
            "surface_code:rotated_memory_z",
            #"color_code:memory_xyz",
            rounds=d * 3,
            distance=d,
            before_round_data_depolarization=p, 
            after_clifford_depolarization=p, 
            before_measure_flip_probability=p, 
            after_reset_flip_probability=p
        ),
        json_metadata={'d': d, 'p': p},
    )
    for d in distances
    for p in dep_error_rates
]

# %%
custom_decoders = {
    "bposd": SinterBpOsdDecoder(
        max_iter=10,
        bp_method="ms",
        ms_scaling_factor=0.625,
        schedule="parallel",
        osd_method="osd0",
        osd_order=0,
    ),

    # Union-find decoder for sinter, adapted from https://github.com/quantumgizmos/ldpc/blob/main/src_python/ldpc/sinter_decoders/sinter_bposd_decoder.py
    "union_find": SinterUnionFindDecoder(
        uf_method='False'
    ),
}

collected_stats1 = sinter.collect(
    num_workers=10,
    tasks=tasks,
    decoders=['pymatching','bposd','union_find'],
    custom_decoders=custom_decoders,
    #max_shots=1_000_000,
    max_shots=10_000,
    max_errors=1000,
)

# %%
fig, ax = plt.subplots(1, 1, figsize=(15,10))
sinter.plot_error_rate(
    ax=ax,
    stats=collected_stats1,
    x_func=lambda stats: stats.json_metadata['p'],
    group_func=lambda stats: f"{stats.decoder},d={stats.json_metadata['d']}",
)
ax.axline((0, 0), slope=1, label='p', linestyle='--', color='black')
ax.loglog()
ax.set_title("Surface Code Error Rates")
ax.set_xlabel("Phyical Error Rate")
ax.set_ylabel("Logical Error Rate per Shot")
ax.grid(which='major')
ax.grid(which='minor')
ax.legend()

# %%
decoders1 = ["pymatching", "bposd", "union_find"]

for decoder in decoders1:
    runtimes_us = []

    for d in distances:
        matching_stats = [
            stat for stat in collected_stats1
            if stat.decoder == decoder
            and stat.json_metadata["d"] == d
        ]

        total_seconds = sum(stat.seconds for stat in matching_stats)
        total_shots = sum(stat.shots for stat in matching_stats)

        runtime_us = 1e6 * total_seconds / total_shots
        runtimes_us.append(runtime_us)

    plt.plot(distances, runtimes_us, marker='o', label=decoder)

plt.xlabel("Distance")
plt.ylabel("Runtime per cycle (μs)")
plt.title("Decoder runtime by distance, Surface code")
plt.xticks(distances)
plt.yscale("log")
plt.grid(True, alpha=0.3)
plt.legend()
plt.show()

# %% [markdown]
# Do the same for colour code with LSD vs OSD decoders

# %%
distances = [3, 5,7]
dep_error_rates = np.linspace(1e-4, 1e-2, 20)

# Source: adapted from https://github.com/quantumlib/Stim/blob/01f1aabd0fbc64d6943d42094a4bde96818399bd/doc/getting_started.ipynb

tasks = [
    sinter.Task(
        circuit=stim.Circuit.generated(
            #"surface_code:rotated_memory_z",
            "color_code:memory_xyz",
            rounds=d * 3,
            distance=d,
            before_round_data_depolarization=p, 
            after_clifford_depolarization=p, 
            before_measure_flip_probability=p, 
            after_reset_flip_probability=p
        ),
        json_metadata={'d': d, 'p': p},
    )
    for d in distances
    for p in dep_error_rates
]

# %%
custom_decoders = {
    "bposd": SinterBpOsdDecoder(
        max_iter=10,
        bp_method="ms",
        ms_scaling_factor=0.625,
        schedule="parallel",
        osd_method="osd0",
        osd_order=0,
    ),

    # Union-find decoder for sinter, adapted from https://github.com/quantumgizmos/ldpc/blob/main/src_python/ldpc/sinter_decoders/sinter_bposd_decoder.py
    "bplsd": SinterLsdDecoder(
        max_iter=3,
        bp_method="ms",
        ms_scaling_factor=0.625,
        schedule="parallel",
        omp_thread_count=1,
        serial_schedule_order=None,
        lsd_order=0,
    ),
}

collected_stats = sinter.collect(
    num_workers=10,
    tasks=tasks,
    decoders=['pymatching','bposd','bplsd'],
    custom_decoders=custom_decoders,
    #max_shots=1_000_000,
    max_shots=10_000,
    max_errors=1000,
)

# %%
fig, ax = plt.subplots(1, 1, figsize=(15,10))
sinter.plot_error_rate(
    ax=ax,
    stats=collected_stats,
    x_func=lambda stats: stats.json_metadata['p'],
    group_func=lambda stats: f"{stats.decoder},d={stats.json_metadata['d']}",
)
ax.axline((0, 0), slope=1, label='p', linestyle='--', color='black')
ax.loglog()
ax.set_title("Steane Code Error Rates")
ax.set_xlabel("Phyical Error Rate")
ax.set_ylabel("Logical Error Rate per Shot")
ax.grid(which='major')
ax.grid(which='minor')
ax.legend()

# %%
decoders = ["pymatching", "bposd", "bplsd"]

for decoder in decoders:
    runtimes_us = []

    for d in distances:
        matching_stats = [
            stat for stat in collected_stats
            if stat.decoder == decoder
            and stat.json_metadata["d"] == d
        ]

        total_seconds = sum(stat.seconds for stat in matching_stats)
        total_shots = sum(stat.shots for stat in matching_stats)

        runtime_us = 1e6 * total_seconds / total_shots
        runtimes_us.append(runtime_us)

    plt.plot(distances, runtimes_us, marker='o', label=decoder)

plt.xlabel("Distance")
plt.ylabel("Runtime per cycle (μs)")
plt.title("Decoder runtime by distance, Steane code")
plt.xticks(distances)
plt.yscale("log")
plt.grid(True, alpha=0.3)
plt.legend()
plt.show()
